# %%
import ast 
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /Users/RobertHolzmann/.cache/huggingface/datasets/lukebarousse___data_jobs/default/0.0.0/1d815e9ce232eb27db11939c44eb048fe6d2e9ab (last modified on Thu Jun 27 12:42:25 2024).

# %%
df_DS_US = df[(df['job_title_short']=='Data Scientist') & (df['job_country']=='United States')].copy()

df_DS_US
# Out:
#        job_title_short                                          job_title  \
# 9       Data Scientist                                  Data Scientist II
# 17      Data Scientist                             Data Science Team Lead
# 32      Data Scientist   Sr. Data Scientist (NLP) - Full-time / Part-time
# 40      Data Scientist        Data Scientist, Data Strategy and Analytics
# 41      Data Scientist                                   Data Scientist I
# ...                ...                                                ...
# 785578  Data Scientist          Data Scientist, Advanced Motor Technology
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785651  Data Scientist             Data Scientist (Supply Chain Security)
# 785673  Data Scientist                    Asset Management Data Scientist
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                            job_via  \
# ...

# %%
df_DS_US_2 = df_DS_US[~df_DS_US['job_location'].isin(['United States', 'Anywhere'])]

# %%
df_plot = df_DS_US_2['job_location'].value_counts().head(10).to_frame()

# %%
import seaborn as sns

sns.set_theme(style='ticks')

sns.barplot(data=df_plot, x = 'count', y='job_location', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Job Postings for Data Scientist in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %%
fig, ax = plt.subplots(1, 3)
fig.set_size_inches(12,5)

dict_column = {
    'job_work_from_home': 'Work From Home', 
    'job_no_degree_mention': 'Job Degree Req.',
    'job_health_insurance': 'Health Insurance Offered'
}

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df_DS_US[column].value_counts(), startangle=90, autopct = '%1.1f%%', labels=[False, True])
    ax[i].set_title(title)

plt.show()

# %%
df_DS_US['job_no_degree_mention'].value_counts()
# Out:
# job_no_degree_mention
# False    57592
# True      1238
# Name: count, dtype: int64

# %%
df_plot = df_DS_US['company_name'].value_counts().head(10).to_frame()


sns.set_theme(style='ticks')

sns.barplot(data=df_plot, x = 'count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Companies for Data Scientist in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()
